# %%
import pandas as pd
import os

# %%
# Define file paths
raw_data_path = '../data/raw/'
processed_data = '../data/processed/'
os.makedirs(processed_data, exist_ok=True)

# %%
# Load all the CSVs
df1 = pd.read_csv(os.path.join(raw_data_path, 'school_alpha.csv'))

# %%
df1
# Out:
#            ID        Full Name     Sex  Maths  English Language  Sci  \
# 0    5506-350       Mary Smith    Male     92                14   71
# 1    2424-704       Mary Moore  Female     82                86   74
# 2    4582-338    James Johnson    Male     99                23    2
# 3    7873-325   Patricia Moore  Female      1                87   29
# 4    3615-814     Robert Smith  Female     63                59   20
# ..        ...              ...     ...    ...               ...  ...
# 195  3306-872    Linda Johnson    Male     16                83   87
# 196  6992-192    Michael Moore  Female      5                52   65
# 197  3024-565     Robert Moore  Female     42                74   22
# 198  7242-942    Robert Taylor  Female     94                74   15
# 199  1410-734  Patricia Wilson  Female      3                55   24
#
#      Attendance %     Term
# 0           74.98  2023_T1
# 1           83.95  2023_T1
# 2           78.37  2024_T1
# ...

# %%
df2 = pd.read_csv(os.path.join(raw_data_path, 'school_beta.csv')) ; df2
# Out:
#     student_id         full_name  gender  math_score  english_score  \
# 0     8606-817  Patricia Johnson  Female        66.0           26.0
# 1     3290-146   Michael Johnson    Male        81.0            NaN
# 2     2592-340     Linda Johnson    Male        89.0           45.0
# 3     9850-529       Linda Davis    Male        46.0           85.0
# 4     7686-386       Mary Wilson    Male         0.0            7.0
# ..         ...               ...     ...         ...            ...
# 195   6095-806     Michael Moore    Male        85.0            4.0
# 196   4618-324      Robert Davis    Male         9.0           86.0
# 197   7121-525       John Wilson  Female         NaN            NaN
# 198   2341-638    Patricia Jones  Female        10.0            NaN
# 199   2838-163  Jennifer Johnson    Male        51.0           81.0
#
#      science_score  attendance_rate     term
# 0             92.0            95.87  2024_T1
# 1             41.0            92.87  2023_T2
# ...

# %%
df3 = pd.read_csv(os.path.join(raw_data_path, 'school_gamma.csv')) ; df3
# Out:
#     student_id         full_name  gender   mathScore   english Score   \
# 0      3695-435  William Williams  Female          12              63
# 1      9008-193   Patricia Taylor  Female          40               0
# 2      9409-525    Linda Williams  Female          28              96
# 3      8575-788       James Moore  Female          59              20
# 4      5169-936      James Miller    Male          33               7
# ..          ...               ...     ...         ...             ...
# 195    5093-196     William Moore  Female          18              27
# 196    1195-163      John Johnson    Male          96              75
# 197    7098-802   Patricia Miller    Male           1              62
# 198    2228-122   Elizabeth Brown    Male          65              50
# 199    2506-967    Linda Williams  Female          13              81
#
#      science_score   attendance     term
# 0                16        91.40  2023_T1
# 1                 1        86.35  2023_T1
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                200 non-null    object
#  1   Full Name         200 non-null    object
#  2   Sex               200 non-null    object
#  3   Maths             200 non-null    int64
#  4   English Language  200 non-null    int64
#  5   Sci               200 non-null    int64
#  6   Attendance %      200 non-null    float64
#  7   Term              200 non-null    object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 12.6+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   student_id       200 non-null    object
#  1   full_name        200 non-null    object
#  2   gender           200 non-null    object
#  3   math_score       188 non-null    float64
#  4   english_score    182 non-null    float64
#  5   science_score    175 non-null    float64
#  6   attendance_rate  200 non-null    float64
#  7   term             200 non-null    object
# dtypes: float64(4), object(4)
# memory usage: 12.6+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0    student_id      200 non-null    object
#  1    full_name       200 non-null    object
#  2    gender          200 non-null    object
#  3    mathScore       200 non-null    int64
#  4    english Score   200 non-null    int64
#  5    science_score   200 non-null    int64
#  6    attendance      200 non-null    float64
#  7    term            200 non-null    object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 12.6+ KB

# %%
df3 = df3[['full_name', 'student_id', 'attendance', 'term']]

# %%
file_names = ['school_alpha.csv', 'school_beta.csv', 'school_gamma.csv']
raw_files = [os.path.join(raw_data_path, f) for f in file_names]

# %%
def clean_data(file_path):
    df = pd.read_csv(file_path)
    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

    column_map = {
    'id': 'student_id',
    'full_name': 'full_name',
    'sex': 'gender',
    'maths': 'math_score',
    'english_language': 'english_score',
    'sci': 'science_score',
    'attendance_%': 'attendance_rate',
    'mathscore': 'math_score',
    'english_score': 'english_score',
    'science_score': 'science_score',
    'attendance': 'attendance_rate',
    'Maths': 'math_score',
    'Sex': 'gender',
}

    df = df.rename(columns=column_map)

    # Clean data
    df['math_score'] = pd.to_numeric(df['math_score'], errors='coerce')
    df['english_score'] = pd.to_numeric(df['english_score'], errors='coerce')
    df['science_score'] = pd.to_numeric(df['science_score'], errors='coerce')
    df['attendance_rate'] = pd.to_numeric(df['attendance_rate'], errors='coerce')


    return df[['student_id', 'full_name', 'gender', 'math_score', 'english_score', 'science_score', 
               'attendance_rate', 'term']]

# %%
all_data = pd.concat([clean_data(file) for file in raw_files], ignore_index=True)

# %%
all_data
# Out:
#     student_id        full_name  gender  math_score  english_score  \
# 0     5506-350       Mary Smith    Male        92.0           14.0
# 1     2424-704       Mary Moore  Female        82.0           86.0
# 2     4582-338    James Johnson    Male        99.0           23.0
# 3     7873-325   Patricia Moore  Female         1.0           87.0
# 4     3615-814     Robert Smith  Female        63.0           59.0
# ..         ...              ...     ...         ...            ...
# 595   5093-196    William Moore  Female        18.0           27.0
# 596   1195-163     John Johnson    Male        96.0           75.0
# 597   7098-802  Patricia Miller    Male         1.0           62.0
# 598   2228-122  Elizabeth Brown    Male        65.0           50.0
# 599   2506-967   Linda Williams  Female        13.0           81.0
#
#      science_score  attendance_rate     term
# 0             71.0            74.98  2023_T1
# 1             74.0            83.95  2023_T1
# ...

# %%
all_data.to_csv(os.path.join(processed_data, 'all_schools_cleaned.csv'), index=False)
print("Data cleaning complete. Processed file saved as 'all_schools_cleaned.csv'.")
# Out:
# Data cleaning complete. Processed file saved as 'all_schools_cleaned.csv'.

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   student_id       600 non-null    object
#  1   full_name        600 non-null    object
#  2   gender           600 non-null    object
#  3   math_score       588 non-null    float64
#  4   english_score    582 non-null    float64
#  5   science_score    575 non-null    float64
#  6   attendance_rate  600 non-null    float64
#  7   term             600 non-null    object
# dtypes: float64(4), object(4)
# memory usage: 37.6+ KB
